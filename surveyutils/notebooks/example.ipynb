# %%
from survey_coverage import get_known_survey_names, get_survey_by_name, get_known_ukirt_surveys, get_known_vista_surveys
import matplotlib.pyplot as plt
# %matplotlib inline
from astropy.wcs import WCS
import numpy as np

# %% [markdown]
# # Get list of surveys that are known

# %%
get_known_survey_names()
# Out:
# ['UKIRT-dxs-H',
#  'UKIRT-dxs-J',
#  'UKIRT-gcs-H',
#  'UKIRT-gcs-J',
#  'UKIRT-gcs-Y',
#  'UKIRT-gps-H',
#  'UKIRT-gps-J',
#  'UKIRT-gps2-H',
#  'UKIRT-las-H',
#  'UKIRT-las-J',
#  'UKIRT-las-Y',
#  'UKIRT-las2-J',
#  'UKIRT-uds-H',
#  'UKIRT-uds-J',
#  'UKIRT-uhs-J',
#  'VISTA-vhs-H',
#  'VISTA-vhs-J',
#  'VISTA-vhs-Y',
#  'VISTA-video-H',
#  'VISTA-video-J',
#  'VISTA-video-Y',
#  'VISTA-viking-H',
#  'VISTA-viking-J',
#  'VISTA-viking-Y',
#  'VISTA-vmc-J',
#  'VISTA-vmc-Y',
#  'VISTA-vvv-H',
#  'VISTA-vvv-J',
#  'VISTA-vvv-Y']

# %% [markdown]
# # Get a specific survey

# %%
survey = get_survey_by_name('UKIRT-uhs-J')
survey2 = get_survey_by_name('UKIRT-las-J')

# %% [markdown]
# # Set up axes and a coordinate system

# %%
fig = plt.figure(figsize=(15,7))

wcs = WCS(naxis=2)
wcs.wcs.ctype = ["RA---AIT", "DEC--AIT"]
wcs.wcs.crval = [0.0, 0.0]
wcs.wcs.cdelt = np.array([-0.675, 0.675])
wcs.wcs.crpix = [240.5, 120.5]

ax = plt.subplot(projection=wcs)

survey.plot_coverage(ax=ax, wcs=wcs, border=True, color='blue', label=f'{survey.survey_name}')
survey2.plot_coverage(ax=ax, wcs=wcs, border=True, color='green', label=f'{survey2.survey_name}')

ax.set_xlabel(r'RA')
ax.set_ylabel(r'Dec')


ax.set_yticklabels([])

ralabel_dec = -20
ra_xlabel, ra_ylabel = wcs.all_world2pix([0, 60, 120, 180, 240, 300],[ralabel_dec]*6, 0)
ra_labels = ['0h', '4h', '8h', '12h', '16h', '20h']

for xcrd, ycrd, ra_label in zip(ra_xlabel, ra_ylabel, ra_labels):
    ax.text(xcrd, ycrd, ra_label, size=14)

#ax.set_xlim(0,480)
plt.legend(bbox_to_anchor=(1.02, 1), fontsize=20)    
plt.grid(color="black", linestyle="dotted")

# %%
# Get all known surveys in J-band
ukirt_surveys = get_known_ukirt_surveys()
ukirt_J_surveys = [x for x in ukirt_surveys if x.filter_name=='J']

vista_surveys = get_known_vista_surveys()
vista_J_surveys = [x for x in vista_surveys if x.filter_name=='J']

wcs = WCS(naxis=2)
wcs.wcs.ctype = ["RA---AIT", "DEC--AIT"]
wcs.wcs.crval = [0.0, 0.0]
wcs.wcs.cdelt = np.array([-0.675, 0.675])
wcs.wcs.crpix = [240.5, 120.5]

fig = plt.figure(figsize=(15,7))
ax = plt.subplot(projection=wcs)

colors = ['blue', 'green','red', 'orange', 'purple', 'yellow', 'gray']
for ind, survey in enumerate(ukirt_J_surveys):
    survey.plot_coverage(ax=ax, wcs=wcs, color=colors[ind], border=True, label=f'{survey.survey_name}')
    
ralabel_dec = -20
ra_xlabel, ra_ylabel = wcs.all_world2pix([0, 60, 120, 180, 240, 300],[ralabel_dec]*6, 0)
ra_labels = ['0h', '4h', '8h', '12h', '16h', '20h']

for xcrd, ycrd, ra_label in zip(ra_xlabel, ra_ylabel, ra_labels):
    ax.text(xcrd, ycrd, ra_label, size=14)
    

declabel_ra = 180
dec_xlabel, dec_ylabel = wcs.all_world2pix([declabel_ra]*2,[-60, 60], 0)
dec_labels = [r'-60$^{o}$', r'60$^{o}$']

for xcrd, ycrd, label in zip(dec_xlabel, dec_ylabel, dec_labels):
    ax.text(xcrd, ycrd, label, size=14)
    
ax.set_xlabel(r"RA")
ax.set_ylabel(r"Dec")

#ax.set_xlim(0,480)
plt.legend(bbox_to_anchor=(1.02, 1), fontsize=20)    
plt.grid(color="black", linestyle="dotted")
plt.savefig(r'ukirt_J_footprint.pdf', bbox_inches='tight')


fig = plt.figure(figsize=(15,7))
ax = plt.subplot(projection=wcs)

colors = ['gray', 'green','red', 'orange', 'purple', 'yellow', 'gray']
for ind, survey in enumerate(vista_J_surveys):
    survey.plot_coverage(ax=ax, wcs=wcs, color=colors[ind], border=True, label=f'{survey.survey_name}')
    
ralabel_dec = -20
ra_xlabel, ra_ylabel = wcs.all_world2pix([0, 60, 120, 180, 240, 300],[ralabel_dec]*6, 0)
ra_labels = ['0h', '4h', '8h', '12h', '16h', '20h']

for xcrd, ycrd, ra_label in zip(ra_xlabel, ra_ylabel, ra_labels):
    ax.text(xcrd, ycrd, ra_label, size=14)
    

declabel_ra = 180
dec_xlabel, dec_ylabel = wcs.all_world2pix([declabel_ra]*2,[-60, 60], 0)
dec_labels = [r'-60$^{o}$', r'60$^{o}$']

for xcrd, ycrd, label in zip(dec_xlabel, dec_ylabel, dec_labels):
    ax.text(xcrd, ycrd, label, size=14)

ax.set_xlabel(r"RA")
ax.set_ylabel(r"Dec")
#ax.set_xlim(0,480)
plt.legend(bbox_to_anchor=(1.02, 1), fontsize=15)    
plt.grid(color="black", linestyle="dotted")
plt.savefig(r'vista_J_footprint.pdf', bbox_inches='tight')

# %% [markdown]
# # Check if given coordinates are covered in a survey

# %%
survey = get_survey_by_name('UKIRT-uhs-J')
survey.contains(ra_deg=[280, 120], dec_deg=[75, 30])
# Out:
# array([False,  True])

# %% [markdown]
# # Get MOC data for a survey, if you want to manipulate it yourself

# %%
survey = get_survey_by_name('UKIRT-uhs-J')
moc = survey.get_moc_data()

# %% [markdown]
# # Add your own survey
#
# Currently, only surveys with MOC coverage can be plotted, more can/will be added as required

# %%
from survey_coverage.surveys import MOCSurvey
MOCSurvey.__doc__
# Out:
# '\n    Class where the survey coverage is given in the healpix multi-order-coverage (MOC)\n    format\n    See : https://www.ivoa.net/documents/MOC/20190215/WD-MOC-1.1-20190215.pdf\n    '

# %%
my_new_survey = MOCSurvey(survey_name='new_survey',
                          coverage_file='path_to_moc_file')
